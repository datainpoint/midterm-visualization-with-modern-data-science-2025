# %%
# !wget -N https://raw.githubusercontent.com/datainpoint/classroom-visualization-and-modern-data-science/main/data/taiwan_election_2024.db

# %%
import unittest
import pandas as pd
import sqlite3

# %%
answer_01 =\
"""
-- BEGIN SOLUTION

-- END SOLUTION
"""

answer_02 =\
"""
-- BEGIN SOLUTION

-- END SOLUTION
"""

answer_03 =\
"""
-- BEGIN SOLUTION

-- END SOLUTION
"""

answer_04 =\
"""
-- BEGIN SOLUTION

-- END SOLUTION
"""

answer_05 =\
"""
-- BEGIN SOLUTION

-- END SOLUTION
"""

answer_06 =\
"""
-- BEGIN SOLUTION

-- END SOLUTION
"""

answer_07 =\
"""
-- BEGIN SOLUTION

-- END SOLUTION
"""

answer_08 =\
"""
-- BEGIN SOLUTION

-- END SOLUTION
"""

answer_09 =\
"""
-- BEGIN SOLUTION

-- END SOLUTION
"""

answer_10 =\
"""
-- BEGIN SOLUTION

-- END SOLUTION
"""

answer_11 =\
"""
-- BEGIN SOLUTION

-- END SOLUTION
"""

answer_12 =\
"""
-- BEGIN SOLUTION

-- END SOLUTION
"""

answer_13 =\
"""
-- BEGIN SOLUTION

-- END SOLUTION
"""

answer_14 =\
"""
-- BEGIN SOLUTION

-- END SOLUTION
"""

answer_15 =\
"""
-- BEGIN SOLUTION

-- END SOLUTION
"""

answer_16 =\
"""
-- BEGIN SOLUTION

-- END SOLUTION
"""

answer_17 =\
"""
-- BEGIN SOLUTION

-- END SOLUTION
"""

answer_18 =\
"""
-- BEGIN SOLUTION

-- END SOLUTION
"""

answer_19 =\
"""
-- BEGIN SOLUTION

-- END SOLUTION
"""

answer_20 =\
"""
-- BEGIN SOLUTION

-- END SOLUTION
"""

# %%
class TestMidterm(unittest.TestCase):
    def test_01(self):
        result_01 = pd.read_sql(answer_01, connection)
        self.assertEqual(result_01.shape, (3, 2))
        tables = result_01.iloc[:, 0].values.tolist()
        self.assertIn("candidates", tables)
        self.assertIn("districts", tables)
        self.assertIn("parties", tables)
        rows = result_01.iloc[:, 1].values.tolist()
        self.assertIn(331, rows)
        self.assertIn(17795, rows)
        self.assertIn(35, rows)
    def test_02(self):
        result_02 = pd.read_sql(answer_02, connection)
        self.assertEqual(result_02.shape, (3, 2))
        tables = result_02.iloc[:, 0].values.tolist()
        self.assertIn("candidates", tables)
        self.assertIn("districts", tables)
        self.assertIn("parties", tables)
        columns = result_02.iloc[:, 1].values.tolist()
        self.assertEqual(11, sum(columns))
    def test_03(self):
        result_03 = pd.read_sql(answer_03, connection)
        self.assertEqual(result_03.shape, (3, 3))
        tables = result_03.iloc[:, 0].values.tolist()
        self.assertIn("candidates", tables)
        self.assertIn("districts", tables)
        self.assertIn("parties", tables)
        rows = result_03.iloc[:, 1].values.tolist()
        self.assertIn(331, rows)
        self.assertIn(17795, rows)
        self.assertIn(35, rows)
        columns = result_03.iloc[:, 2].values.tolist()
        self.assertEqual(11, sum(columns))
    def test_04(self):
        result_04 = pd.read_sql(answer_04, connection)
        self.assertEqual(result_04.shape, (2, 2))
        vote_tallied_at = result_04.iloc[:, 1].values.astype(str).tolist()
        self.assertIn("2024-01-13 16:30:49", vote_tallied_at)
        self.assertIn("2024-01-13 21:56:59", vote_tallied_at)
    def test_05(self):
        result_05 = pd.read_sql(answer_05, connection)
        self.assertEqual(result_05.shape, (2, 4))
        counties = result_05.iloc[:, 0].values.tolist()
        self.assertIn("新竹縣", counties)
        self.assertIn("宜蘭縣", counties)
        towns = result_05.iloc[:, 1].values.tolist()
        self.assertIn("竹北市", towns)
        self.assertIn("大同鄉", towns)
    def test_06(self):
        result_06 = pd.read_sql(answer_06, connection)
        self.assertEqual(result_06.shape, (10, 2))
        vote_tallied_at = result_06.iloc[:, 1].values.astype(str).tolist()
        self.assertIn("2024-01-13 16:30:49", vote_tallied_at)
        self.assertIn("2024-01-13 21:56:59", vote_tallied_at)
    def test_07(self):
        result_07 = pd.read_sql(answer_07, connection)
        self.assertEqual(result_07.shape, (10, 4))
        counties = result_07.iloc[:, 0].values.tolist()
        self.assertIn("新竹縣", counties)
        self.assertIn("宜蘭縣", counties)
        towns = result_07.iloc[:, 1].values.tolist()
        self.assertIn("竹北市", towns)
        self.assertIn("大同鄉", towns)
    def test_08(self):
        result_08 = pd.read_sql(answer_08, connection)
        self.assertEqual(result_08.shape, (2, 2))
        votes = result_08.iloc[:, 1].values.tolist()
        self.assertIn(158596, votes)
        self.assertIn(136, votes)
    def test_09(self):
        result_09 = pd.read_sql(answer_09, connection)
        self.assertEqual(result_09.shape, (2, 4))
        legislator_regions = result_09.iloc[:, 0].values.tolist()
        self.assertIn("新北市第1選舉區", legislator_regions)
        self.assertIn("臺北市第8選舉區", legislator_regions)
        parties = result_09.iloc[:, 1].values.tolist()
        self.assertIn("中國國民黨", parties)
        self.assertIn("興中同盟會", parties)
        candidates = result_09.iloc[:, 2].values.tolist()
        self.assertIn("洪孟楷", candidates)
        self.assertIn("胡之壯", candidates)
    def test_10(self):
        result_10 = pd.read_sql(answer_10, connection)
        self.assertEqual(result_10.shape, (309, 4))
        parties = result_10.iloc[:, 1].unique().tolist()
        self.assertIn("中國國民黨", parties)
        self.assertIn("台灣民眾黨", parties)
        self.assertIn("民主進步黨", parties)
        self.assertIn("無", parties)
    def test_11(self):
        result_11 = pd.read_sql(answer_11, connection)
        self.assertEqual(result_11.shape, (20, 4))
        parties = result_11.iloc[:, 1].values.tolist()
        self.assertIn("民主進步黨", parties)
        self.assertIn("中國國民黨", parties)
        names = result_11.iloc[:, 2].values.tolist()
        self.assertIn("林俊憲", names)
        self.assertIn("黃捷", names)
        self.assertIn("萬美玲", names)
        self.assertIn("李彥秀", names)
    def test_12(self):
        result_12 = pd.read_sql(answer_12, connection)
        self.assertEqual(result_12.shape, (73, 4))
        parties = result_12.iloc[:, 1].values.tolist()
        self.assertIn("民主進步黨", parties)
        self.assertIn("中國國民黨", parties)
        self.assertIn("無", parties)
        names = result_12.iloc[:, 2].values.tolist()
        self.assertIn("林俊憲", names)
        self.assertIn("黃捷", names)
        self.assertIn("萬美玲", names)
        self.assertIn("李彥秀", names)
    def test_13(self):
        result_13 = pd.read_sql(answer_13, connection)
        self.assertEqual(result_13.shape, (37, 4))
        parties = result_13.iloc[:, 1].values.tolist()
        self.assertIn("中國國民黨", parties)
        self.assertIn("無", parties)
        names = result_13.iloc[:, 2].values.tolist()
        self.assertIn("萬美玲", names)
        self.assertIn("李彥秀", names)
        self.assertIn("王鴻薇", names)
        self.assertIn("徐巧芯", names)
    def test_14(self):
        result_14 = pd.read_sql(answer_14, connection)
        self.assertEqual(result_14.shape, (16, 2))
        parties = result_14.iloc[:, 0].values.tolist()
        self.assertIn("時代力量", parties)
        self.assertIn("小民參政歐巴桑聯盟", parties)
        self.assertIn("民主進步黨", parties)
        self.assertIn("中國國民黨", parties)
        self.assertIn("台灣民眾黨", parties)
    def test_15(self):
        result_15 = pd.read_sql(answer_15, connection)
        self.assertEqual(result_15.shape, (13, 2))
        parties = result_15.iloc[:, 0].values.tolist()
        self.assertIn("時代力量", parties)
        self.assertIn("小民參政歐巴桑聯盟", parties)
        self.assertNotIn("民主進步黨", parties)
        self.assertNotIn("中國國民黨", parties)
        self.assertNotIn("台灣民眾黨", parties)
    def test_16(self):
        result_16 = pd.read_sql(answer_16, connection)
        self.assertEqual(result_16.shape, (66, 3))
        counties = result_16.iloc[:, 0].unique()
        self.assertEqual(counties.size, 22)
        candidates = result_16.iloc[:, 1].unique()
        self.assertEqual(candidates.size, 3)
    def test_17(self):
        result_17 = pd.read_sql(answer_17, connection)
        self.assertEqual(result_17.shape, (22, 3))
        counties = result_17.iloc[:, 0].values
        self.assertEqual(counties.size, 22)
        candidates = result_17.iloc[:, 1].values.tolist()
        self.assertIn("賴清德/蕭美琴", candidates)
        self.assertIn("侯友宜/趙少康", candidates)
        self.assertNotIn("柯文哲/吳欣盈", candidates)
    def test_18(self):
        result_18 = pd.read_sql(answer_18, connection)
        self.assertEqual(result_18.shape, (12, 4))
        counties = result_18.iloc[:, 0].unique()
        self.assertEqual(counties.size, 1)
        towns = result_18.iloc[:, 1].values
        self.assertEqual(towns.size, 12)
        candidates = result_18.iloc[:, 2].unique()
        self.assertEqual(candidates.size, 2)
    def test_19(self):
        result_19 = pd.read_sql(answer_19, connection)
        self.assertEqual(result_19.shape, (158, 4))
        counties = result_19.iloc[:, 0].unique()
        self.assertEqual(counties.size, 6)
    def test_20(self):
        result_20 = pd.read_sql(answer_20, connection)
        self.assertEqual(result_20.shape, (9, 3))
        types = result_20.iloc[:, 0].unique()
        self.assertEqual(types.size, 3)
        parties = result_20.iloc[:, 1].unique()
        self.assertEqual(parties.size, 3)

connection = sqlite3.connect("taiwan_election_2024.db")
suite = unittest.TestLoader().loadTestsFromTestCase(TestMidterm)
runner = unittest.TextTestRunner(verbosity=2)
test_results = runner.run(suite)
number_of_failures = len(test_results.failures)
number_of_errors = len(test_results.errors)
number_of_test_runs = test_results.testsRun
number_of_successes = number_of_test_runs - (number_of_failures + number_of_errors)
print(f"You've got {number_of_successes} successes among {number_of_test_runs} questions.")
